# %%
import pandas

# %%
data_frame=pandas.read_csv('/content/sample_data/image_train_data.csv')

# %%
data_frame
# Out:
#           Date  Sensex_value  Nifty_value  22k gold price  24k gold price
# 0   11-07-2022       54363.0      16199.0            4680            4914
# 1   12-07-2022       53840.0      16037.0            4670            4904
# 2   13-07-2022       53549.0      15975.0            4660            4893
# 3   14-07-2022       53449.0      15947.0            4660            4893
# 4   15-07-2022       53786.0      16052.0            4676            4910
# 5   16-07-2022           NaN          NaN            4627            4858
# 6   17-07-2022           NaN          NaN            4627            4858
# 7   18-07-2022       54533.0      16281.0            4647            4879
# 8   19-07-2022       54723.0      16329.0            4658            4891
# 9   20-07-2022       55302.0      16495.0            4667            4900
# 10  21-07-2022       55703.0      16609.0            4630            4862
# 11  22-07-2022       56052.0      16714.0            4666            4899
# ...

# %% [markdown]
# Filling NaN values with mean of that column

# %%
data_frame['Sensex_value'].fillna(data_frame['Sensex_value'].mean(),inplace=True)

# %%
data_frame['Nifty_value'].fillna(data_frame['Nifty_value'].mean(),inplace=True)

# %%
data_frame
# Out:
#           Date  Sensex_value   Nifty_value  22k gold price  24k gold price
# 0   11-07-2022  54363.000000  16199.000000            4680            4914
# 1   12-07-2022  53840.000000  16037.000000            4670            4904
# 2   13-07-2022  53549.000000  15975.000000            4660            4893
# 3   14-07-2022  53449.000000  15947.000000            4660            4893
# 4   15-07-2022  53786.000000  16052.000000            4676            4910
# 5   16-07-2022  56124.590909  16733.090909            4627            4858
# 6   17-07-2022  56124.590909  16733.090909            4627            4858
# 7   18-07-2022  54533.000000  16281.000000            4647            4879
# 8   19-07-2022  54723.000000  16329.000000            4658            4891
# 9   20-07-2022  55302.000000  16495.000000            4667            4900
# 10  21-07-2022  55703.000000  16609.000000            4630            4862
# ...

# %% [markdown]
# Filling NaN values with mode of that column

# %%
data_frame=pandas.read_csv('/content/sample_data/image_train_data.csv')

# %%
data_frame['Sensex_value'].fillna(data_frame['Sensex_value'].mode(),inplace=True)

# %%
data_frame['Nifty_value'].fillna(data_frame['Nifty_value'].mode(),inplace=True)

# %%
data_frame
# Out:
#           Date  Sensex_value  Nifty_value  22k gold price  24k gold price
# 0   11-07-2022       54363.0      16199.0            4680            4914
# 1   12-07-2022       53840.0      16037.0            4670            4904
# 2   13-07-2022       53549.0      15975.0            4660            4893
# 3   14-07-2022       53449.0      15947.0            4660            4893
# 4   15-07-2022       53786.0      16052.0            4676            4910
# 5   16-07-2022       54533.0      16281.0            4627            4858
# 6   17-07-2022       54723.0      16329.0            4627            4858
# 7   18-07-2022       54533.0      16281.0            4647            4879
# 8   19-07-2022       54723.0      16329.0            4658            4891
# 9   20-07-2022       55302.0      16495.0            4667            4900
# 10  21-07-2022       55703.0      16609.0            4630            4862
# 11  22-07-2022       56052.0      16714.0            4666            4899
# ...

# %% [markdown]
# filling NaN values with median of that column

# %%
data_frame=pandas.read_csv('/content/sample_data/image_train_data.csv')

# %%
data_frame['Sensex_value'].fillna(data_frame['Sensex_value'].median(),inplace=True)

# %%
data_frame['Nifty_value'].fillna(data_frame['Nifty_value'].median(),inplace=True)

# %%
data_frame
# Out:
#           Date  Sensex_value  Nifty_value  22k gold price  24k gold price
# 0   11-07-2022       54363.0      16199.0            4680            4914
# 1   12-07-2022       53840.0      16037.0            4670            4904
# 2   13-07-2022       53549.0      15975.0            4660            4893
# 3   14-07-2022       53449.0      15947.0            4660            4893
# 4   15-07-2022       53786.0      16052.0            4676            4910
# 5   16-07-2022       55763.0      16626.0            4627            4858
# 6   17-07-2022       55763.0      16626.0            4627            4858
# 7   18-07-2022       54533.0      16281.0            4647            4879
# 8   19-07-2022       54723.0      16329.0            4658            4891
# 9   20-07-2022       55302.0      16495.0            4667            4900
# 10  21-07-2022       55703.0      16609.0            4630            4862
# 11  22-07-2022       56052.0      16714.0            4666            4899
# ...

# %% [markdown]
# Filling NaN values with Standard Deviation of that Column

# %%
data_frame=pandas.read_csv('/content/sample_data/image_train_data.csv')

# %%
data_frame['Sensex_value'].fillna(data_frame['Sensex_value'].std(),inplace=True)

# %%
data_frame['Nifty_value'].fillna(data_frame['Nifty_value'].std(),inplace=True)

# %%
data_frame
# Out:
#           Date  Sensex_value   Nifty_value  22k gold price  24k gold price
# 0   11-07-2022    54363.0000  16199.000000            4680            4914
# 1   12-07-2022    53840.0000  16037.000000            4670            4904
# 2   13-07-2022    53549.0000  15975.000000            4660            4893
# 3   14-07-2022    53449.0000  15947.000000            4660            4893
# 4   15-07-2022    53786.0000  16052.000000            4676            4910
# 5   16-07-2022     1839.3331    542.492037            4627            4858
# 6   17-07-2022     1839.3331    542.492037            4627            4858
# 7   18-07-2022    54533.0000  16281.000000            4647            4879
# 8   19-07-2022    54723.0000  16329.000000            4658            4891
# 9   20-07-2022    55302.0000  16495.000000            4667            4900
# 10  21-07-2022    55703.0000  16609.000000            4630            4862
# ...

# %% [markdown]
# Filling the NaN values with minimum value of that column

# %%
data_frame=pandas.read_csv('/content/sample_data/image_train_data.csv')

# %%
data_frame['Sensex_value'].fillna(min(data_frame['Sensex_value']),inplace=True)

# %%
data_frame['Nifty_value'].fillna(min(data_frame['Nifty_value']),inplace=True)

# %%
data_frame
# Out:
#           Date  Sensex_value  Nifty_value  22k gold price  24k gold price
# 0   11-07-2022       54363.0      16199.0            4680            4914
# 1   12-07-2022       53840.0      16037.0            4670            4904
# 2   13-07-2022       53549.0      15975.0            4660            4893
# 3   14-07-2022       53449.0      15947.0            4660            4893
# 4   15-07-2022       53786.0      16052.0            4676            4910
# 5   16-07-2022       53449.0      15947.0            4627            4858
# 6   17-07-2022       53449.0      15947.0            4627            4858
# 7   18-07-2022       54533.0      16281.0            4647            4879
# 8   19-07-2022       54723.0      16329.0            4658            4891
# 9   20-07-2022       55302.0      16495.0            4667            4900
# 10  21-07-2022       55703.0      16609.0            4630            4862
# 11  22-07-2022       56052.0      16714.0            4666            4899
# ...

# %% [markdown]
# Filling NaN values with maximum value of that column

# %%
data_frame=pandas.read_csv('/content/sample_data/image_train_data.csv')

# %%
data_frame['Sensex_value'].fillna(max(data_frame['Sensex_value']),inplace=True)

# %%
data_frame['Nifty_value'].fillna(max(data_frame['Nifty_value']),inplace=True)

# %%
data_frame
# Out:
#           Date  Sensex_value  Nifty_value  22k gold price  24k gold price
# 0   11-07-2022       54363.0      16199.0            4680            4914
# 1   12-07-2022       53840.0      16037.0            4670            4904
# 2   13-07-2022       53549.0      15975.0            4660            4893
# 3   14-07-2022       53449.0      15947.0            4660            4893
# 4   15-07-2022       53786.0      16052.0            4676            4910
# 5   16-07-2022       58853.0      17525.0            4627            4858
# 6   17-07-2022       58853.0      17525.0            4627            4858
# 7   18-07-2022       54533.0      16281.0            4647            4879
# 8   19-07-2022       54723.0      16329.0            4658            4891
# 9   20-07-2022       55302.0      16495.0            4667            4900
# 10  21-07-2022       55703.0      16609.0            4630            4862
# 11  22-07-2022       56052.0      16714.0            4666            4899
# ...
